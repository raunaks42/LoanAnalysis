# %%
import pandas as pd
from sklearn import linear_model
import numpy as np
from sklearn.metrics import r2_score
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
plt.style.use('dark_background')

df=pd.read_csv("C:/Users/rauna/Desktop/IDS Project/credit_train_clean_sample_no_outliers2.csv")
df=df.sample(n=5000)
X = df[['Current Credit Balance','Number of Open Accounts']]
X1=df['Current Credit Balance']
X2=df['Number of Open Accounts']
Y = df['Maximum Open Credit']

B1,B0=np.polyfit(X1,Y,deg=1)
yp1=B0+(B1*X1)

b1,b0=np.polyfit(X2,Y,deg=1)
yp2=b0+(b1*X2)
'''
regr = linear_model.LinearRegression()
regr.fit(X, Y)
print('Intercept: \n', regr.intercept_)
print('Coefficients: \n', regr.coef_)
New_Current_Credit_Balance = int(input("Current Credit Balance:"))
New_Number_of_Open_Accounts = int(input("Number of Open Accounts:"))
print ('Predicted Maximum Open Credit: \n', regr.predict([[New_Current_Credit_Balance ,New_Number_of_Open_Accounts]]))

print(r2_score(Y,yp1))
plt.figure(figsize=(20,10))
plt.plot("Current Credit Balance", "Maximum Open Credit", data=df,linestyle='',marker='o',markersize=3,color='red')
ax=plt.gca()
ax.set_facecolor("black")
plt.xlabel("Current Credit Balance")
plt.ylabel("Maximum Open Credit")
plt.plot(X1,yp1,linewidth=5,color='gold')
plt.show()
'''
print(r2_score(Y,yp2))
plt.figure(figsize=(20,10))
plt.plot("Number of Open Accounts", "Maximum Open Credit", data=df,linestyle='',marker='o',markersize=3,color='blue')
ax=plt.gca()
ax.set_facecolor("black")
plt.xlabel("Number of Open Accounts")
plt.ylabel("Maximum Open Credit")
plt.plot(X2,yp2,linewidth=5,color='silver')
'''
xx1, xx2 = np.meshgrid(np.linspace(df["Current Credit Balance"].min(), df["Current Credit Balance"].max(), 100),np.linspace(df["Number of Open Accounts"].min(), df["Number of Open Accounts"].max(), 100))
Z = regr.intercept_ + regr.coef_[0] * xx1 + regr.coef_[1] * xx2
fig = plt.figure(figsize=(12, 8))
ax = Axes3D(fig, azim=-115, elev=15)
surf = ax.plot_surface(xx1, xx2, Z, cmap=plt.cm.RdBu_r, alpha=0.6, linewidth=0)
resid = Y - (regr.intercept_ + regr.coef_[0] * X1 + regr.coef_[1] * X2)
ax.scatter(X[resid >= 0]["Current Credit Balance"], X[resid >= 0]["Number of Open Accounts"], Y[resid >= 0], color='black', alpha=1.0, facecolor='gold')
ax.scatter(X[resid < 0]["Current Credit Balance"], X[resid < 0]["Number of Open Accounts"], Y[resid < 0], color='black', alpha=1.0, facecolor='silver')
ax.xaxis.pane.fill = False
ax.yaxis.pane.fill = False
ax.zaxis.pane.fill = False
ax.set_xlabel('Current Credit Balance')
ax.set_ylabel('Number of Open Accounts')
ax.set_zlabel('Maximum Open Credit')
'''
# Out:
# 0.16784272374374987
# ...
