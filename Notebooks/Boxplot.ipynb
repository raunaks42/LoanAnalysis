# %%
import pandas as pd
#data_clean=pd.read_csv("C:/Users/rauna/Desktop/IDS Project/credit_train_clean_sample.csv")
#data_clean=pd.read_csv("C:/Users/rauna/Desktop/IDS Project/credit_train_clean_sample_no_outliers1.csv")
data_clean=pd.read_csv("C:/Users/rauna/Desktop/IDS Project/credit_train_clean_sample_no_outliers2.csv")
box_clean=data_clean.boxplot(column='Maximum Open Credit')
